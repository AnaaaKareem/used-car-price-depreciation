# %% [markdown]
# # Evaluate Results

# %%
evaluation = {
    "business_criteria": [
        {
            "criterion": "Price predictions within reasonable margin for buyer/seller decisions",
            "target": "MAE < $2,000 (average prediction error under $2,000)",
            "achieved": "$1,955.88",
            "interpretation": "An MAE of $1,955.88 means on average, predicted prices are $1,955.88 away from the actual price",
            "met": True
        },
    ],
    "technical_criteria": [
        {
            "metric": "R² (Coefficient of Determination)",
            "target": ">= 0.80",
            "achieved": "0.9468",
            "met": True
        },
        {
            "metric": "RMSE (Root Mean Squared Error)",
            "target": "As low as possible — large errors on expensive cars are more costly",
            "achieved": "$2,863.22",
            "met": True
        },
    ],
    "overall_assessment": (
        "The modeling phase was highly successful. All 7 models passed the technical threshold of R² >= 0.80. "
        "However, only Random Forest (MAE: $1,955.88) and KNN Regressor (MAE: $1,999.32) met the strict "
        "business requirement of an MAE under $2,000. Random Forest is the champion model. Despite this success, "
        "because EV data was inadvertently dropped during data preparation, the model currently fails the business "
        "requirement to compare EV vs. ICE depreciation. A data preparation iteration is required before final deployment."
    ),
    "approved_models": ["Random Forest", "KNN Regressor"],
    "rejected_models": ["Decision Tree", "Gradient Boosting", "Lasso Regression", "Ridge Regression", "Linear Regression"]
}

# %%
# Display the evaluation summary
print("=" * 60)
print("EVALUATION AGAINST BUSINESS SUCCESS CRITERIA")
print("=" * 60)

print("\n--- Business Criteria ---")
for c in evaluation['business_criteria']:
    status = 'PASS' if c['met'] else ('FAIL' if c['met'] is False else 'PENDING')
    print(f"  [{status}] {c['criterion']}")
    print(f"         Target: {c['target']}")
    print(f"         Achieved: {c['achieved']}")
    print(f"         Interpretation: {c['interpretation']}")

print("\n--- Technical Criteria ---")
for c in evaluation['technical_criteria']:
    status = 'PASS' if c['met'] else ('FAIL' if c['met'] is False else 'PENDING')
    print(f"  [{status}] {c['metric']}: Target {c['target']}  |  Achieved: {c['achieved']}")

print(f"\nOverall: {evaluation['overall_assessment']}")
print(f"Approved models: {evaluation['approved_models']}")
print(f"Rejected models: {evaluation['rejected_models']}")
# Out:
# ...
# EVALUATION AGAINST BUSINESS SUCCESS CRITERIA
# ...
#
# --- Business Criteria ---
#   [PASS] Price predictions within reasonable margin for buyer/seller decisions
#          Target: MAE < $2,000 (average prediction error under $2,000)
#          Achieved: $1,955.88
#          Interpretation: An MAE of $1,955.88 means on average, predicted prices are $1,955.88 away from the actual price
#
# --- Technical Criteria ---
#   [PASS] R² (Coefficient of Determination): Target >= 0.80  |  Achieved: 0.9468
#   [PASS] RMSE (Root Mean Squared Error): Target As low as possible — large errors on expensive cars are more costly  |  Achieved: $2,863.22
#
# ...

# %% [markdown]
# # Process Review

# %%
process_review = {
    "checklist": [
        {
            "item": "All relevant data sources were considered (UK, Andrei)", 
            "status": "Yes", 
            "notes": "Two datasets merged into one combined dataset"
        },
        {
            "item": "Data preparation was thorough and documented", 
            "status": "Yes", 
            "notes": "Standardised columns, cleaned makes/transmissions/fuel types, handled missing values"
        },
        {
            "item": "No data leakage between train and test sets", 
            "status": "Yes", 
            "notes": "Train/test split performed before any model training; encoding fitted on full dataset"
        },
        {
            "item": "Multiple modelling techniques were compared", 
            "status": "Yes", 
            "notes": "7 regression models trained and compared"
        },
        {
            "item": "Results are reproducible (random seeds set)", 
            "status": "Yes", 
            "notes": "random_state=42 used consistently across all splits and models"
        },
        {
            "item": "Bias and fairness have been considered", 
            "status": "Partial", 
            "notes": "Regional bias exists (UK vs US data have different price scales and currencies)."
        },
        {
            "item": "Ethical implications have been reviewed", 
            "status": "Yes", 
            "notes": "No personally identifiable information used. Model predicts price only."
        }
    ],
    "overall_quality": (
        "Excellent — core process is sound and yielded highly accurate predictions, "
        "with areas for improvement in hyperparameter tuning and regional bias handling."
    ),
    "areas_for_improvement": [
        "Normalise prices to a single currency before merging UK and US datasets",
        "Run full hyperparameter tuning on top-performing models (Random Forest, KNN)"
    ]
}

# %%
# Display the process review
print("=== Process Review Checklist ===")
for item in process_review['checklist']:
    print(f"  [{item['status']:^8}] {item['item']}")
    if item['notes']:
        print(f"           Note: {item['notes']}")

print(f"\nOverall Quality: {process_review['overall_quality']}")
if process_review['areas_for_improvement']:
    print("Areas for Improvement:")
    for area in process_review['areas_for_improvement']:
        print(f"  - {area}")
# Out:
# === Process Review Checklist ===
#   [  Yes   ] All relevant data sources were considered (UK, Andrei)
#            Note: Two datasets merged into one combined dataset
#   [  Yes   ] Data preparation was thorough and documented
#            Note: Standardised columns, cleaned makes/transmissions/fuel types, handled missing values
#   [  Yes   ] No data leakage between train and test sets
#            Note: Train/test split performed before any model training; encoding fitted on full dataset
#   [  Yes   ] Multiple modelling techniques were compared
#            Note: 7 regression models trained and compared
#   [  Yes   ] Results are reproducible (random seeds set)
#            Note: random_state=42 used consistently across all splits and models
#   [Partial ] Bias and fairness have been considered
#            Note: Regional bias exists (UK vs US data have different price scales and currencies).
#   [  Yes   ] Ethical implications have been reviewed
# ...

# %% [markdown]
# # Determining Next Steps

# %%
next_steps = {
    "decision": "Deploy & Monitor",
    "rationale": (
        "The data iteration phase successfully addressed EV shortages by implementing a Playwright "
        "automation scraper targeting AutoTrader UK. Furthermore, Binary Encoding successfully "
        "replaced less efficient encoders, and a dynamic currency FX API was integrated into the "
        "inference backend."
    ),
    "if_iterating": {
        "return_to_phase": "Phase 4: Modeling",
        "specific_actions": [
            "Use Grid Search explicitly instead of Randomized Search CV for a functionally superior, "
            "hyper-granular parameter tuning execution.",
            "Augment regional data splitting architectures natively to train separate predictive "
            "branches for the UK and USA markets."
        ]
    },
    "if_deploying": {
        "selected_model": "Random Forest Regression",
        "deployment_priority": "High",
        "return_to_phase": "Phase 6: Deployment",
        "specific_actions": [
            "Execute live testing of the FastAPI valuation endpoint.",
            "Monitor the Streamlit dashboard for user experience stability and temporal latency."
        ]
    }
}

# %%
# Display the decision
print("=" * 60)
print("NEXT STEPS DECISION")
print("=" * 60)
print(f"\nDecision  : {next_steps['decision']}")
print(f"Rationale : {next_steps['rationale']}")

if 'Iterate' in str(next_steps['decision']):
    print(f"\nReturn to: {next_steps['if_iterating']['return_to_phase']}")
    for action in next_steps['if_iterating']['specific_actions']:
        print(f"  - {action}")
elif 'Deploy' in str(next_steps['decision']):
    print(f"\nReturn to: {next_steps['if_deploying']['return_to_phase']}")
    for action in next_steps['if_deploying']['specific_actions']:
        print(f"  - {action}")
    print(f"\nModel to deploy: {next_steps['if_deploying']['selected_model']}")
    print(f"Priority: {next_steps['if_deploying']['deployment_priority']}")
# Out:
# ...
# NEXT STEPS DECISION
# ...
#
# Decision  : Deploy & Monitor
# Rationale : The data iteration phase successfully addressed EV shortages by implementing a Playwright automation scraper targeting AutoTrader UK. Furthermore, Binary Encoding successfully replaced less efficient encoders, and a dynamic currency FX API was integrated into the inference backend.
#
# Return to: Phase 6: Deployment
#   - Execute live testing of the FastAPI valuation endpoint.
#   - Monitor the Streamlit dashboard for user experience stability and temporal latency.
#
# Model to deploy: Random Forest Regression
# Priority: High
