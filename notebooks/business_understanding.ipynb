# %% [markdown]
# # Business Understanding

# %% [markdown]
# ### Determining Business Objectives

# %%
business_objectives = {
    "background": "Due to the uncertainty of vehicle valuation, Dealership and second-hand car platform often face a prominent financial risk when pricing used vehicles for trade-ins and resale, as the traditional method of valuing often relies on static 'book values' or subjective experience (human intuition) rather than data-driven insights, which fails to account for dynamic market factors and complex non-linear relationships between variables.",
    "primary_objective": "Predict the resale price of a vehicle based on it’s attributes using a machine learning model allowing dealership and second hand car platforms to set offers that guarantees a specific profit margin.",
    "success_criteria": [
        "Secure Targeted Profit Margins: Eliminate excessive compensation by implementing a pricing model that ensures a baseline gross profit margin of no less than ten percent upon the resale.",
        "Capture Valuation Factors: Identify the attributes with the most noticeable impact on the vehicle’s resale price wither it is for internal combustion engines (odometer) or electric vehicles (battery health).",
        "Evaluate Vehicle Realistically: Utilize a data-driven pricing methodology as opposed to depending on subjective “expertise” or a uniform valuation, while accounting for variables that are not linearly quantifiable.",
        "Coping with Market Shocks: Adjust pricing strategies, especially concerning electric vehicles, to alleviate financial risk stemming from sudden market variances, such as immediate modifications in government subsidies."
    ]
}

# %% [markdown]
# # Display Business Objectives

# %%
# Display the defined objectives in a readable format
for key, value in business_objectives.items():
    print(f">> {key.upper().replace('_', ' ')}:")
    if isinstance(value, list):
        for item in value:
            print(f"   - {item}")
    else:
        print(f"   {value}")
    print()

# %% [markdown]
# ### Assessing Situation

# %%
situation_assessment = {
    "resources": {
        "personnel": ["Data Analyst: The data scientist, responsible for the data analysis and model’s development.", "Project Supervisor: Available for high-level guidance, validation of methodology, and project oversight."],
        "data_sources": ["Kaggle Used Car Datasets (CSV, 10,000+ records) with features: Year, Model, Price, Transmission, Mileage, FuelType, Tax, MPG, EngineSize."],
        "computing": "Personal Laptop (16 GB RAM) and Google Colab if the dataset size causes memory issues or if models require GPU acceleration.",
        "software": ["Python (Primarily For Regression Models)", "R (For Data Analytics)", "Jupyter Notebooks/VS Code", "scikit-learn", "pandas", "matplotlib", "seaborn"]
    },
    "requirements": [
        "Implement a minimum of three distinct regression models.",
        "Explicitly evaluate the hypothesis that 'Electric Vehicles depreciate at a faster or different rate compared to Petrol vehicles.'",
        "Incorporate suitable error metrics (RMSE, MAE, R2).",
        "A minimum of 5 charts must be provided in the report and presentations."
    ],
    "assumptions": [
        "Market Stability: Relationships among Year, Mileage, and Price remain steady.",
        "Data Integrity: Price values correspond to legitimate market transactions.",
        "Proxy Variables: Year and mileage act as sufficient proxies for battery degradation.",
        "Dealer Profit Standardization: Dealerships aim for at least a 10% profit margin."
    ],
    "constraints": [
        "Missing Features: Absence of 'Vehicle Condition' or 'Accident History'.",
        "Temporal Relevance: Dataset is historical and may not accurately forecast prices in current times.",
        "EV Data Scarcity: Electric Vehicles often constitute less than 5% of the dataset.",
        "Economical Factors Exclusion: Neglects external variables like inflation or interest rates."
    ],
    "risks_and_contingencies": [
        {"risk": "Insufficient EV data", "probability": "High", "mitigation": "Combine hybrid vehicles, reduce scope to brand-only analysis"},
        {"risk": "Poor model performance", "probability": "Medium", "mitigation": "Explore alternative regression algorithms or feature engineering"},
        {"risk": "Overfitting", "probability": "Medium", "mitigation": "Cross-validation, early stopping, simpler models"}
    ],
    "terminology": {
        "ICE": "Internal Combustion Engine",
        "EV": "Electric Vehicle",
        "Depreciation": "The reduction in the value of a vehicle in relation to features/attributes over time."
    },
    "cost_benefit": "Costs: Development time and model maintenance. Benefits: Reduced overpayment, faster/consistent pricing decisions, and guaranteed profit margins."
}

# %% [markdown]
# # Display Situation Assessment

# %%
import json
print(json.dumps(situation_assessment, indent=2))

# %% [markdown]
# ### Determining Data Mining Goals

# %%
data_mining_goals = {
    "problem_type": "Regression",
    "target_variable": "Price",
    "technical_goals": [
        "Price Prediction Model Development (5+ regression models)",
        "Profit Margin Prediction Framework (10% margin calculator)",
        "Petrol vs. EV Depreciation Comparison (statistical hypothesis testing)",
        "Feature Importance Analysis (mileage, year, brand impact)"
    ],
    "success_metrics": [
        "Secure an R2 score exceeding 0.80.",
        "Attain a Root Mean Squared Error (RMSE) or a Mean Absolute Percentage Error (MAPE) that is low to ensure commercial viability.",
        "Model Deployment: Interface that enables inputting vehicle characteristics to receive predicted resale price."
    ]
}

# %% [markdown]
# # Display Data Mining Goals

# %%
# Display the mapping from business objectives to data mining goals
print("=" * 60)
print("BUSINESS TO DATA MINING GOAL MAPPING")
print("=" * 60)
print(f"\nBusiness Objective : {business_objectives['primary_objective']}")
print(f"Problem Type       : {data_mining_goals['problem_type']}")
print(f"Target Variable    : {data_mining_goals['target_variable']}")
print(f"\nTechnical Goals:")
for goal in data_mining_goals['technical_goals']:
    print(f"  - {goal}")
print(f"\nSuccess Metrics:")
for metric in data_mining_goals['success_metrics']:
    print(f"  - {metric}")

# %% [markdown]
# ### Produce Project Plan

# %%
project_plan = {
    "tools": ["Python", "R", "pandas", "scikit-learn", "matplotlib", "seaborn", "XGBoost"],
    "techniques": ["Regression Analysis", "Linear Regression", "Random Forest", "K-Means Clustering"],
    "timeline": [
        {"phase": "Data Understanding",  "duration": "Week 1-2", "status": "Not Started"},
        {"phase": "Data Preparation",    "duration": "Week 2-4", "status": "Not Started"},
        {"phase": "Modelling",           "duration": "Week 4-5", "status": "Not Started"},
        {"phase": "Evaluation",          "duration": "Week 5-6", "status": "Not Started"},
        {"phase": "Deployment",          "duration": "Week 6",   "status": "Not Started"}
    ],
    "dependencies": [
        "Data access must be granted before Data Understanding can begin.",
        "Model maintenance requires quarterly retraining to account for new models."
    ],
    "tool_justification": "Python is primarily for regression models and scikit-learn for machine learning algorithms, while R is used for broader data analytics."
}

# %% [markdown]
# # Display project plan

# %%
print("=" * 60)
print("PROJECT PLAN")
print("=" * 60)

print("\nTools:", ", ".join(project_plan['tools']) if project_plan['tools'] else "[Not yet defined]")
print("Techniques:", ", ".join(project_plan['techniques']) if project_plan['techniques'] else "[Not yet defined]")

print("\nTimeline:")
if project_plan['timeline']:
    for phase in project_plan['timeline']:
        print(f"  [{phase.get('status', 'N/A'):^12}] {phase['phase']:<25} | {phase['duration']}")
else:
    print("  [Not yet defined]")

print("\nDependencies:")
for dep in project_plan['dependencies']:
    print(f"  - {dep}")

print(f"\nTool Justification: {project_plan['tool_justification']}")

# %% [markdown]
# # # Display Overall Summary

# %%
print("=" * 60)
print("PHASE 1 SUMMARY: BUSINESS UNDERSTANDING")
print("=" * 60)
print(f"\nPrimary Objective  : {business_objectives['primary_objective']}")
print(f"Problem Type       : {data_mining_goals['problem_type']}")
print(f"Target Variable    : {data_mining_goals['target_variable']}")
print(f"Tools Planned      : {', '.join(project_plan['tools']) if project_plan['tools'] else 'TBD'}")
print(f"Techniques Planned : {', '.join(project_plan['techniques']) if project_plan['techniques'] else 'TBD'}")
